# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitusomu25/python_lab/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Addition of numbers

# %%
print(2+5)
# Out:
# 7

# %%
print(2+3+5)
# Out:
# 10
